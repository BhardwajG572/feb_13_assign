# %%
# explain why we have to use the exception class while creating a custom exception ?

# %% [raw]
# Using custom exception classes in programming is a
# best practice that helps improve code organization, maintainability, and clarity.we use exception class while creating a custom exception
# selective handling : different exceptions might require different handling mechanisms . custom exception classes allow you to catch and handle specific exceptions at different levels of our application's architecture.
#     This selective handling enhances our ability to respong appropriately to various error scenarios.
#     Testing and Debugging: With custom exception classes, you can create targeted unit tests for each type of exception, ensuring that they are properly raised and handled.
#         This can improve the reliability and robustness of your code by catching potential issues early in the development process.
#
#
#     Clarity and Readability: Custom exception classes provide descriptive and meaningful names for the specific errors or exceptional situations that can occur in your code. This makes it easier for developers (including yourself and others) to understand what went wrong when an exception is raised. A well-named custom exception class can act as self-documentation for your codebase

# %%
#Write a python program to print Python Exception Hierarchy.

# %%
def print_exception_hierarchy(exception_class, indent=0):
    print(' ' * indent + str(exception_class))
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)

print_exception_hierarchy(BaseException)
# Out:
# <class 'BaseException'>
#     <class 'Exception'>
#         <class 'TypeError'>
#             <class 'decimal.FloatOperation'>
#             <class 'email.errors.MultipartConversionError'>
#         <class 'StopAsyncIteration'>
#         <class 'StopIteration'>
#         <class 'ImportError'>
#             <class 'ModuleNotFoundError'>
#                 <class 'setuptools._vendor.importlib_metadata.PackageNotFoundError'>
#                 <class 'importlib_metadata.PackageNotFoundError'>
#             <class 'zipimport.ZipImportError'>
#         <class 'OSError'>
#             <class 'ConnectionError'>
#                 <class 'BrokenPipeError'>
#                 <class 'ConnectionAbortedError'>
#                 <class 'ConnectionRefusedError'>
#                 <class 'ConnectionResetError'>
#                     <class 'http.client.RemoteDisconnected'>
#             <class 'BlockingIOError'>
#             <class 'ChildProcessError'>
#             <class 'FileExistsError'>
# ...

# %%
#Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [raw]
# The ArithmeticError class in Python is a base class for exceptions that occur during arithmetic operations.
# It serves as a parent class for several specific arithmetic-related exceptions.
# Two of the exceptions that are derived from ArithmeticError are ZeroDivisionError and OverflowError.
#
# >ZeroDivisionError :
#     try:
#     result = 10 / 0
#     except ZeroDivisionError as e:
#     print("Error:", e)
#
#
# > OverflowError:

# %%
#  Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [raw]
# The LookupError class in Python is a base class for exceptions that occur when a specified key or index is not found during lookups in various data structures like dictionaries, lists, or tuples. It provides a way to handle situations where an attempt to access a non-existent element in a collection is made. Two specific exceptions that are derived from LookupError are KeyError and IndexError.
#
# keyerror::This exception is raised when you try to access a dictionary key that does not exist.
#
#
#
# my_dict = {'a': 1, 'b': 2, 'c': 3}
# try:
#     value = my_dict['x']  # Attempt to access a non-existent key
# except KeyError as e:
#     print("Error:", e)
#
#
#     output : Error:'x'
#
#
#
#     IndexError:
# This exception is raised when you try to access a list or tuple element using an index that is out of bounds.
#
#
# my_list = [10, 20, 30, 40, 50]
# try:
#     value = my_list[10]  # Attempt to access an out-of-bounds index
# except IndexError as e:
#     print("Error:", e)
#
# Both KeyError and IndexError are specific cases of lookup failures, and they provide valuable information about what went wrong during the lookup operation. By using these specific exception classes, you can handle these situations more gracefully and provide appropriate error handling or recovery mechanisms.
# The LookupError class serves as a convenient parent class for these and other lookup-related exceptions, allowing you to catch and handle them in a unified way when appropriate.

# %%
# Explain ImportError. What is ModuleNotFoundError?

# %% [raw]
# try:
#     import my_modlue  # There's a typo in the module name
# except ImportError as e:
#     print("Import Error:", e)ImportError:
#
# ImportError is an exception in Python that is raised when an import statement fails to locate or load a module. It occurs when the Python interpreter cannot find the specified module in the search paths or when there is an issue with the module's content that prevents it from being imported correctly.
#
#
# Common scenarios that can trigger an ImportError include:
#
# Attempting to import a module that doesn't exist or
# Using an incorrect module name or path in the import statement or
# Errors in the module's code that prevent it from being successfully imported.
#
#
#
#
# ModuleNotFoundError:
#
# ModuleNotFoundError is a more specific exception that inherits from ImportError. It is raised when an import statement specifically fails to locate the module being imported. In other words, it's raised when Python cannot find the module you're trying to import.
#
# To summarize, both ImportError and ModuleNotFoundError are exceptions raised when there are issues with importing modules in Python.

# %%
# List down some best practices for exception handling in python.

# %% [raw]
# Exception handling is a crucial aspect of writing reliable and robust Python code. Here are some best practices for effective exception handling in Python:
#
# Use Specific Exception Types: Catch only the exceptions you can handle and be as specific as possible. Avoid using a bare except clause, which can catch unexpected errors and make debugging difficult. Instead, catch only the specific exception types you anticipate and can handle.
#
# Keep Exception Blocks Short: Place only the minimum necessary code within a try block. This helps localize the potential source of the exception and improves code readability.
#
# Avoid Exception Suppression: Avoid using empty except blocks, as they can suppress errors and make debugging challenging. If you don't know how to handle an exception, it's better to let it propagate up the call stack.
#
# Clean Up with finally: Use the finally block to ensure that essential cleanup code (such as closing files or releasing resources) is executed, regardless of whether an exception occurred.
#
# Use Context Managers (with Statements): Use context managers (with statements) for resources that need to be acquired and released, such as files, network connections, and database connections. Context managers ensure proper cleanup even if exceptions are raised.
#
# Handle Specific Errors: Handle specific exceptions separately to provide meaningful error messages and appropriate recovery actions. This enhances code maintainability and user experience.
#
# Log Exceptions: Use a logging framework (e.g., Python's logging module) to log exceptions. This aids in diagnosing issues and understanding the behavior of your code in different scenarios.
#
# Don't Catch SystemExit: Avoid catching SystemExit exceptions, which are raised when the program exits using the sys.exit() function. If you need to perform cleanup before exiting, use an atexit handler or finally block.
#
# Create Custom Exception Classes: For specific error scenarios in your codebase, create custom exception classes. This helps you provide informative error messages and allows for targeted exception handling.
#
# Reraise Exceptions: If you catch an exception but can't handle it, you can reraise it using the raise statement without any arguments. This preserves the original exception information.
#
# Document Exception Expectations: Document the types of exceptions that your functions/methods may raise. Use docstrings to indicate what specific exceptions callers should be aware of.
#
# Avoid Catching Base Exceptions: Avoid catching overly broad exceptions like Exception or BaseException, as this can hide critical errors. Instead, catch more specific exceptions based on the situation.
#
# Use try-except Inside Loops: When working with loops, consider placing the try-except block inside the loop if you want the loop to continue executing even when an exception occurs.
#
# Test Exception Handling: Write unit tests that cover different exception scenarios to ensure your code behaves correctly in exceptional cases.
#
# Handle Expected Failures Gracefully: Design your code to gracefully handle expected failures and recoverable errors. Provide appropriate user feedback or alternative paths when errors occur.
#
# By following these best practices, we can write more robust and maintainable Python code that gracefully handles exceptional situations and provides a better user experience.
